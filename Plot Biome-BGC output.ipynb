# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

bgcout_fname = 'rme_test0_ann.txt'

# %%
df_rme = pd.read_csv(bgcout_fname,sep=' ',skipinitialspace=True,skiprows=9)
df_rme
# Out:
#       year  annPRCP  annTavg  maxLAI  annET  annOF  annNPP  annNBP
# 0     2005   1065.0      6.0     0.0  126.7  601.2     3.9     3.7
# 1     2006   1005.6      5.7     0.0  127.4  996.8     8.4     7.8
# 2     2007    749.6      6.3     0.1  110.9  572.5    11.0     9.8
# 3     2008   1065.0      6.0     0.1  147.8  863.8    12.4    10.3
# 4     2009   1005.6      5.7     0.2  148.5  974.7    12.5     9.3
# ...    ...      ...      ...     ...    ...    ...     ...     ...
# 2995  5000   1005.6      5.7     2.8  420.4  742.7   155.7    10.8
# 2996  5001    749.6      6.3     2.8  373.1  326.2    95.4   -54.4
# 2997  5002   1065.0      6.0     2.7  421.3  536.5   195.2    43.7
# 2998  5003   1005.6      5.7     2.8  420.4  742.7   155.7    10.8
# 2999  5004    749.6      6.3     2.8  373.1  326.2    95.4   -54.4
#
# [3000 rows x 8 columns]

# %%
plt.figure(figsize=(14,10))
plt.rcParams.update({'font.size': 16})
plt.plot(df_rme['year'],df_rme['annNPP'])
plt.xlabel('Simulation Year')
plt.ylabel('Annual Net Primary Productivity [gC/m${}^2$/yr]')
# Out:
# Text(0, 0.5, 'Annual Net Primary Productivity [gC/m${}^2$/yr]')
